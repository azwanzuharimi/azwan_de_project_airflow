# %%
# !pip install snowflake-connector-python
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import snowflake.connector

# %%
ACCOUNT = 'UFIJDLY-NF47757'
# PASSWORD = 
# WAREHOUSE = ''

# %%
ctx = snowflake.connector.connect(user='azwan92',
                            password='Akenapa92!',
                            account=ACCOUNT,
                            warehouse='COMPUTE_WH',
                            database='COFFEE',
                            schema='RAW',
                            role='ACCOUNTADMIN')

# %%
ctx.execute_string
# Out:
# <bound method SnowflakeConnection.execute_string of <snowflake.connector.connection.SnowflakeConnection object at 0x0000013B7F457DD0>>

# %%
# a = ctx.execute_string("SELECT * FROM COFFEE.raw.fact_sales limit 100",)

# %%
a = ctx.cursor().execute("SELECT * FROM COFFEE.raw.fact_sales limit 100")

# %%
a.fetch_pandas_all()
# Out:
#     TRANSACTION_ID  TRANSACTION_DATE TRANSACTION_TIME  TRANSACTION_QTY  \
# 0                1  1672531200000000         07:06:11                2
# 1                2  1672531200000000         07:08:56                2
# 2                3  1672531200000000         07:14:04                2
# 3                4  1672531200000000         07:20:24                1
# 4                5  1672531200000000         07:22:41                2
# ..             ...               ...              ...              ...
# 95              96  1672531200000000         10:35:47                1
# 96              97  1672531200000000         10:41:53                1
# 97              98  1672531200000000         10:47:53                2
# 98              99  1672531200000000         10:49:13                2
# 99             100  1672531200000000         10:49:51                2
#
#     STORE_ID   STORE_LOCATION  PRODUCT_ID  UNIT_PRICE    PRODUCT_CATEGORY  \
# ...

# %%
# https://docs.snowflake.com/en/developer-guide/python-connector/python-connector-api#write_pandas
# https://www.youtube.com/watch?v=OLXkGB7krGo
